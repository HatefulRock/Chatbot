# %% [markdown]
# <a href="https://colab.research.google.com/github/HatefulRock/Chatbot/blob/main/EmbedchainRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install embedchain
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import os
# Replace this with your HF token
os.environ["HUGGINGFACE_ACCESS_TOKEN"] = "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"



config = {
  'llm': {
    'provider': 'huggingface',
    'config': {
      'model': 'mistralai/Mistral-7B-Instruct-v0.2',
      'top_p': 0.5
    }
  },
  'embedder': {
    'provider': 'huggingface',
    'config': {
      'model': 'sentence-transformers/all-mpnet-base-v2'
    }
  }
}
from embedchain import App
app = App.from_config(config=config)
app.add('/content/data/Les congés maternité et paternité.pdf', data_type='pdf_file')
print("asking query")
answer=app.query("Combien de jours de congés pour une mère?")
print(answer)
# Out:
# Doc content has not changed. Skipping creating chunks and embeddings
# asking query
#
# You are a Q&A expert system. Your responses must always be rooted in the context provided for each query. Here are some guidelines to follow:
#
# 1. Refrain from explicitly mentioning the context provided in your response.
# 2. The context should silently guide your answers without being directly acknowledged.
# 3. Do not use phrases such as 'According to the context provided', 'Based on the context, ...' etc.
#
# Context information:
# ----------------------
# ...

# %%
answer=app.query("Combien de jours de congés pour un père?")
print(answer)
# Out:
# You are a Q&A expert system. Your responses must always be rooted in the context provided for each query. Here are some guidelines to follow:
#
# 1. Refrain from explicitly mentioning the context provided in your response.
# 2. The context should silently guide your answers without being directly acknowledged.
# 3. Do not use phrases such as 'According to the context provided', 'Based on the context, ...' etc.
#
# Context information:
# ----------------------
# ...
